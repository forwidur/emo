# %%
import logging
import random
import requests
import urllib
import json

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from gensim.models import doc2vec
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, classification_report, precision_recall_curve

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

airtable_list_url = 'https://api.airtable.com/v0/appasJt3vfOA4OjKU/Posts'
airtable_api_key = 'keyvHKcZudc4sSbpZ'
airtable_headers = {'Authorization': 'Bearer ' + airtable_api_key, 'Content-type': 'application/json'}

# %%
# TODO convert this to work with our data set
def read_dataset():
    posts_raw = []
    labels_raw = []
    
    offset = False

    while(True):
        formula = urllib.parse.urlencode({'filterByFormula': '{On Topic}!=""'})
    
        if (offset):
            airtable_list_url = 'https://api.airtable.com/v0/appasJt3vfOA4OjKU/Posts?offset=' + offset + '&' + formula
        else:
            airtable_list_url = 'https://api.airtable.com/v0/appasJt3vfOA4OjKU/Posts?' + formula
    
        response = requests.get(airtable_list_url, headers = {'Authorization': 'Bearer ' + airtable_api_key})
        payload = json.loads(response.content)
        
        if not 'records' in payload:
            print(payload)
            raise RuntimeError()
    
        for post in payload['records']:
            if 'Text' in post['fields'] and len(post['fields']['Text']) > 50:
                posts_raw.append(post['fields']['Text'])
                labels_raw.append(post['fields']['On Topic'])
                
        if 'offset' in payload:
            offset = payload['offset']
        else:
            break
    
    posts_series = pd.Series(posts_raw)
    labels_series = pd.Series(labels_raw)
    
    # TODO consider getting more negative data, since we're non representative
    x_train, x_test, y_train, y_test = train_test_split(posts_series, labels_series, random_state=0, test_size=0.2)
    
    # do the all all data set for initial doc2vec construction
    offset = False
    all_posts_raw = []
    while(True):
        formula = urllib.parse.urlencode({'filterByFormula': '{Text}!=""'})
    
        if (offset):
            airtable_list_url = 'https://api.airtable.com/v0/appasJt3vfOA4OjKU/Posts?offset=' + offset + '&' + formula
        else:
            airtable_list_url = 'https://api.airtable.com/v0/appasJt3vfOA4OjKU/Posts?' + formula
    
        response = requests.get(airtable_list_url, headers = {'Authorization': 'Bearer ' + airtable_api_key})
        payload = json.loads(response.content)
        
        if not 'records' in payload:
            print(payload)
            raise RuntimeError()
    
        for post in payload['records']:
            if 'Text' in post['fields'] and len(post['fields']['Text']) > 50:
                all_posts_raw.append(post['fields']['Text'])
        if 'offset' in payload:
            offset = payload['offset']
        else:
            break
    
    x_train = label_sentences(x_train, 'Train')
    x_test = label_sentences(x_test, 'Test')
    all_data = label_sentences(pd.Series(all_posts_raw), 'All') + x_train + x_test
    
    return x_train, x_test, y_train, y_test, all_data


def get_vectors(doc2vec_model, corpus_size, vectors_size, vectors_type):
    """
    Get vectors from trained doc2vec model
    :param doc2vec_model: Trained Doc2Vec model
    :param corpus_size: Size of the data
    :param vectors_size: Size of the embedding vectors
    :param vectors_type: Training or Testing vectors
    :return: list of vectors
    """
    vectors = np.zeros((corpus_size, vectors_size))
    for i in range(0, corpus_size):
        prefix = vectors_type + '_' + str(i)
        vectors[i] = doc2vec_model.docvecs[prefix]
    return vectors


def train_doc2vec(corpus):
    logging.info("Building Doc2Vec vocabulary")
    # TODO consider tweaking min_count to be higher
    d2v = doc2vec.Doc2Vec(min_count=1,  # Ignores all words with total frequency lower than this
                          window=10,  # The maximum distance between the current and predicted word within a sentence
                          vector_size=300,  # Dimensionality of the generated feature vectors
                          workers=5,  # Number of worker threads to train the model
                          alpha=0.025,  # The initial learning rate
                          min_alpha=0.00025,  # Learning rate will linearly drop to min_alpha as training progresses
                          dm=1)  # dm defines the training algorithm. If dm=1 means ‘distributed memory’ (PV-DM)
                                 # and dm =0 means ‘distributed bag of words’ (PV-DBOW)
    d2v.build_vocab(corpus)

    logging.info("Training Doc2Vec model")
    # 10 epochs take around 10 minutes on my machine (i7), if you have more time/computational power make it 20
    for epoch in range(10):
        logging.info('Training iteration #{0}'.format(epoch))
        d2v.train(corpus, total_examples=d2v.corpus_count, epochs=d2v.iter)
        # shuffle the corpus
        random.shuffle(corpus)
        # decrease the learning rate
        d2v.alpha -= 0.0002
        # fix the learning rate, no decay
        d2v.min_alpha = d2v.alpha

    logging.info("Saving trained Doc2Vec model")
    d2v.save("d2v.model")
    return d2v


def train_classifier(d2v, training_vectors, training_labels):
    logging.info("Classifier training")
    train_vectors = get_vectors(d2v, len(training_vectors), 300, 'Train')
    # TODO consider trying this with decision tree
    # TODO consider running this sample set through MonkeyLearn
    #model = LogisticRegression()
    model = GradientBoostingClassifier()
    model.fit(train_vectors, np.array(training_labels))
    training_predictions = model.predict(train_vectors)
    logging.info('Training predicted classes: {}'.format(np.unique(training_predictions)))
    logging.info('Training accuracy: {}'.format(accuracy_score(training_labels, training_predictions)))
    print(classification_report(training_labels, training_predictions))
    logging.info('Training F1 score: {}'.format(f1_score(training_labels, training_predictions, average='weighted')))
    return model


def test_classifier(d2v, classifier, testing_vectors, testing_labels):
    logging.info("Classifier testing")
    test_vectors = get_vectors(d2v, len(testing_vectors), 300, 'Test')
    testing_predictions = classifier.predict(test_vectors)
    logging.info('Testing predicted classes: {}'.format(np.unique(testing_predictions)))
    print(classification_report(testing_labels, testing_predictions))
    logging.info('Testing accuracy: {}'.format(accuracy_score(testing_labels, testing_predictions)))
    logging.info('Testing F1 score: {}'.format(f1_score(testing_labels, testing_predictions, average='weighted')))

# %%
def label_sentences(corpus, label_type):
    """
    Gensim's Doc2Vec implementation requires each document/paragraph to have a label associated with it.
    We do this by using the LabeledSentence method. The format will be "TRAIN_i" or "TEST_i" where "i" is
    a dummy index of the review.
    """
    labeled = []
    for i, v in enumerate(corpus):
        label = label_type + '_' + str(i)
        labeled.append(doc2vec.TaggedDocument(v.split(), [label]))
    return labeled

# %%
x_train, x_test, y_train, y_test, all_data = read_dataset()

# %%
d2v_model = train_doc2vec(all_data)
# Out:
# 2018-09-04 23:34:45,792 : INFO : Building Doc2Vec vocabulary
# 2018-09-04 23:34:45,793 : INFO : collecting all words and their counts
# 2018-09-04 23:34:45,795 : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# 2018-09-04 23:34:47,591 : INFO : collected 215976 word types and 8586 unique tags from a corpus of 8586 examples and 7020856 words
# 2018-09-04 23:34:47,591 : INFO : Loading a fresh vocabulary
# 2018-09-04 23:34:48,392 : INFO : effective_min_count=1 retains 215976 unique words (100% of original 215976, drops 0)
# 2018-09-04 23:34:48,392 : INFO : effective_min_count=1 leaves 7020856 word corpus (100% of original 7020856, drops 0)
# 2018-09-04 23:34:49,013 : INFO : deleting the raw counts dictionary of 215976 items
# 2018-09-04 23:34:49,018 : INFO : sample=0.001 downsamples 37 most-common words
# 2018-09-04 23:34:49,020 : INFO : downsampling leaves estimated 5718415 word corpus (81.4% of prior 7020856)
# 2018-09-04 23:34:49,661 : INFO : estimated required memory for 215976 words and 300 dimensions: 638350800 bytes
# 2018-09-04 23:34:49,662 : INFO : resetting layer weights
# 2018-09-04 23:34:53,408 : INFO : Training Doc2Vec model
# 2018-09-04 23:34:53,408 : INFO : Training iteration #0
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:109: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
# 2018-09-04 23:34:53,409 : INFO : training model with 5 workers on 215976 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 2018-09-04 23:34:54,416 : INFO : EPOCH 1 - PROGRESS: at 6.92% examples, 419045 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:34:55,422 : INFO : EPOCH 1 - PROGRESS: at 14.87% examples, 431944 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:34:56,471 : INFO : EPOCH 1 - PROGRESS: at 23.01% examples, 440036 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:34:57,477 : INFO : EPOCH 1 - PROGRESS: at 31.40% examples, 445733 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:34:58,478 : INFO : EPOCH 1 - PROGRESS: at 39.63% examples, 448311 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:34:59,530 : INFO : EPOCH 1 - PROGRESS: at 47.40% examples, 444284 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:00,533 : INFO : EPOCH 1 - PROGRESS: at 54.83% examples, 442536 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:01,534 : INFO : EPOCH 1 - PROGRESS: at 62.90% examples, 445693 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:02,534 : INFO : EPOCH 1 - PROGRESS: at 70.63% examples, 446630 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:03,534 : INFO : EPOCH 1 - PROGRESS: at 78.26% examples, 447369 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:04,560 : INFO : EPOCH 1 - PROGRESS: at 86.52% examples, 447589 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:05,561 : INFO : EPOCH 1 - PROGRESS: at 94.90% examples, 447039 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:06,157 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-09-04 23:35:06,177 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-09-04 23:35:06,200 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-04 23:35:06,202 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-04 23:35:06,206 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-04 23:35:06,207 : INFO : EPOCH - 1 : training on 7020856 raw words (5728121 effective words) took 12.8s, 447801 effective words/s
# 2018-09-04 23:35:07,234 : INFO : EPOCH 2 - PROGRESS: at 7.13% examples, 425131 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:08,237 : INFO : EPOCH 2 - PROGRESS: at 14.88% examples, 432753 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:09,254 : INFO : EPOCH 2 - PROGRESS: at 21.97% examples, 420462 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:10,275 : INFO : EPOCH 2 - PROGRESS: at 29.41% examples, 417038 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:11,279 : INFO : EPOCH 2 - PROGRESS: at 37.26% examples, 420366 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:12,305 : INFO : EPOCH 2 - PROGRESS: at 44.47% examples, 421708 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:13,323 : INFO : EPOCH 2 - PROGRESS: at 52.27% examples, 423240 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:14,340 : INFO : EPOCH 2 - PROGRESS: at 60.05% examples, 424700 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:15,343 : INFO : EPOCH 2 - PROGRESS: at 66.66% examples, 419704 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:16,352 : INFO : EPOCH 2 - PROGRESS: at 73.25% examples, 418289 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:17,387 : INFO : EPOCH 2 - PROGRESS: at 80.83% examples, 419016 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:18,393 : INFO : EPOCH 2 - PROGRESS: at 88.62% examples, 420043 words/s, in_qsize 9, out_qsize 1
# 2018-09-04 23:35:19,412 : INFO : EPOCH 2 - PROGRESS: at 97.13% examples, 421000 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:19,735 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-09-04 23:35:19,771 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-09-04 23:35:19,786 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-04 23:35:19,791 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-04 23:35:19,826 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-04 23:35:19,827 : INFO : EPOCH - 2 : training on 7020856 raw words (5728090 effective words) took 13.6s, 420726 effective words/s
# 2018-09-04 23:35:20,842 : INFO : EPOCH 3 - PROGRESS: at 6.17% examples, 367925 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:21,844 : INFO : EPOCH 3 - PROGRESS: at 13.41% examples, 389069 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:22,872 : INFO : EPOCH 3 - PROGRESS: at 20.82% examples, 401406 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:23,880 : INFO : EPOCH 3 - PROGRESS: at 28.79% examples, 411363 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:24,883 : INFO : EPOCH 3 - PROGRESS: at 36.76% examples, 415481 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:25,889 : INFO : EPOCH 3 - PROGRESS: at 43.84% examples, 417927 words/s, in_qsize 10, out_qsize 0
# 2018-09-04 23:35:26,905 : INFO : EPOCH 3 - PROGRESS: at 51.41% examples, 416393 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:27,915 : INFO : EPOCH 3 - PROGRESS: at 58.94% examples, 419068 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:28,921 : INFO : EPOCH 3 - PROGRESS: at 66.14% examples, 418512 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:29,922 : INFO : EPOCH 3 - PROGRESS: at 72.61% examples, 416676 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:30,948 : INFO : EPOCH 3 - PROGRESS: at 79.73% examples, 415318 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:31,949 : INFO : EPOCH 3 - PROGRESS: at 87.21% examples, 415410 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:32,956 : INFO : EPOCH 3 - PROGRESS: at 95.38% examples, 416088 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:33,523 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-09-04 23:35:33,540 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-09-04 23:35:33,542 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-04 23:35:33,546 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-04 23:35:33,573 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-04 23:35:33,573 : INFO : EPOCH - 3 : training on 7020856 raw words (5726489 effective words) took 13.7s, 416701 effective words/s
# 2018-09-04 23:35:34,580 : INFO : EPOCH 4 - PROGRESS: at 6.92% examples, 418472 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:35,585 : INFO : EPOCH 4 - PROGRESS: at 14.02% examples, 409657 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:36,597 : INFO : EPOCH 4 - PROGRESS: at 20.60% examples, 401818 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:37,641 : INFO : EPOCH 4 - PROGRESS: at 27.25% examples, 390730 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:38,671 : INFO : EPOCH 4 - PROGRESS: at 34.27% examples, 385788 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:39,691 : INFO : EPOCH 4 - PROGRESS: at 40.74% examples, 381452 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:40,694 : INFO : EPOCH 4 - PROGRESS: at 47.46% examples, 381536 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:41,709 : INFO : EPOCH 4 - PROGRESS: at 54.55% examples, 385420 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:42,715 : INFO : EPOCH 4 - PROGRESS: at 60.89% examples, 383265 words/s, in_qsize 10, out_qsize 0
# 2018-09-04 23:35:43,721 : INFO : EPOCH 4 - PROGRESS: at 68.34% examples, 386812 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:44,774 : INFO : EPOCH 4 - PROGRESS: at 75.20% examples, 390805 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:45,791 : INFO : EPOCH 4 - PROGRESS: at 82.54% examples, 390314 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:46,805 : INFO : EPOCH 4 - PROGRESS: at 89.39% examples, 389543 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:47,828 : INFO : EPOCH 4 - PROGRESS: at 96.31% examples, 386748 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:48,360 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-09-04 23:35:48,368 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-09-04 23:35:48,371 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-04 23:35:48,377 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-04 23:35:48,404 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-04 23:35:48,405 : INFO : EPOCH - 4 : training on 7020856 raw words (5726247 effective words) took 14.8s, 386207 effective words/s
# 2018-09-04 23:35:49,426 : INFO : EPOCH 5 - PROGRESS: at 5.72% examples, 337024 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:50,444 : INFO : EPOCH 5 - PROGRESS: at 9.73% examples, 287492 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:51,480 : INFO : EPOCH 5 - PROGRESS: at 14.05% examples, 267978 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:52,483 : INFO : EPOCH 5 - PROGRESS: at 17.58% examples, 252079 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:53,500 : INFO : EPOCH 5 - PROGRESS: at 23.01% examples, 264354 words/s, in_qsize 10, out_qsize 0
# 2018-09-04 23:35:54,508 : INFO : EPOCH 5 - PROGRESS: at 29.44% examples, 277987 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:55,533 : INFO : EPOCH 5 - PROGRESS: at 35.38% examples, 285924 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:56,537 : INFO : EPOCH 5 - PROGRESS: at 42.02% examples, 296744 words/s, in_qsize 10, out_qsize 0
# 2018-09-04 23:35:57,552 : INFO : EPOCH 5 - PROGRESS: at 49.14% examples, 308435 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:58,557 : INFO : EPOCH 5 - PROGRESS: at 56.77% examples, 320177 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:35:59,559 : INFO : EPOCH 5 - PROGRESS: at 63.06% examples, 325202 words/s, in_qsize 10, out_qsize 0
# 2018-09-04 23:36:00,571 : INFO : EPOCH 5 - PROGRESS: at 70.34% examples, 332968 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:01,577 : INFO : EPOCH 5 - PROGRESS: at 77.39% examples, 340351 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:02,593 : INFO : EPOCH 5 - PROGRESS: at 85.28% examples, 346121 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:03,599 : INFO : EPOCH 5 - PROGRESS: at 93.05% examples, 351852 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:04,478 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-09-04 23:36:04,480 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-09-04 23:36:04,489 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-04 23:36:04,522 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-04 23:36:04,540 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-04 23:36:04,541 : INFO : EPOCH - 5 : training on 7020856 raw words (5726287 effective words) took 16.1s, 355081 effective words/s
# 2018-09-04 23:36:04,542 : INFO : training on a 35104280 raw words (28635234 effective words) took 71.1s, 402574 effective words/s
# 2018-09-04 23:36:04,559 : INFO : Training iteration #1
# 2018-09-04 23:36:04,560 : WARNING : Effective 'alpha' higher than previous training cycles
# 2018-09-04 23:36:04,561 : INFO : training model with 5 workers on 215976 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 2018-09-04 23:36:05,583 : INFO : EPOCH 1 - PROGRESS: at 7.06% examples, 406248 words/s, in_qsize 10, out_qsize 0
# 2018-09-04 23:36:06,584 : INFO : EPOCH 1 - PROGRESS: at 13.37% examples, 384532 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:07,591 : INFO : EPOCH 1 - PROGRESS: at 20.00% examples, 386337 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:08,619 : INFO : EPOCH 1 - PROGRESS: at 28.00% examples, 398326 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:09,623 : INFO : EPOCH 1 - PROGRESS: at 35.07% examples, 398653 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:10,625 : INFO : EPOCH 1 - PROGRESS: at 42.63% examples, 402082 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:11,627 : INFO : EPOCH 1 - PROGRESS: at 50.49% examples, 407480 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:12,661 : INFO : EPOCH 1 - PROGRESS: at 58.65% examples, 412546 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:13,673 : INFO : EPOCH 1 - PROGRESS: at 66.41% examples, 415305 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:14,691 : INFO : EPOCH 1 - PROGRESS: at 73.21% examples, 413961 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:15,705 : INFO : EPOCH 1 - PROGRESS: at 80.32% examples, 413180 words/s, in_qsize 10, out_qsize 0
# 2018-09-04 23:36:16,713 : INFO : EPOCH 1 - PROGRESS: at 88.07% examples, 416070 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:17,730 : INFO : EPOCH 1 - PROGRESS: at 95.85% examples, 417523 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:18,201 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-09-04 23:36:18,213 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-09-04 23:36:18,237 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-04 23:36:18,252 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-04 23:36:18,257 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-04 23:36:18,258 : INFO : EPOCH - 1 : training on 7020856 raw words (5728046 effective words) took 13.7s, 418526 effective words/s
# 2018-09-04 23:36:19,264 : INFO : EPOCH 2 - PROGRESS: at 7.10% examples, 412405 words/s, in_qsize 8, out_qsize 1
# 2018-09-04 23:36:20,269 : INFO : EPOCH 2 - PROGRESS: at 14.77% examples, 423750 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:21,276 : INFO : EPOCH 2 - PROGRESS: at 22.40% examples, 428798 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:22,286 : INFO : EPOCH 2 - PROGRESS: at 29.14% examples, 419814 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:23,305 : INFO : EPOCH 2 - PROGRESS: at 35.94% examples, 410139 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:24,335 : INFO : EPOCH 2 - PROGRESS: at 43.09% examples, 404522 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:25,342 : INFO : EPOCH 2 - PROGRESS: at 49.91% examples, 400627 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:26,343 : INFO : EPOCH 2 - PROGRESS: at 57.28% examples, 403967 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:27,364 : INFO : EPOCH 2 - PROGRESS: at 65.19% examples, 406999 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:28,399 : INFO : EPOCH 2 - PROGRESS: at 71.34% examples, 403490 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:29,400 : INFO : EPOCH 2 - PROGRESS: at 78.09% examples, 402230 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:30,403 : INFO : EPOCH 2 - PROGRESS: at 85.93% examples, 405464 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:31,415 : INFO : EPOCH 2 - PROGRESS: at 93.68% examples, 407733 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:32,181 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-09-04 23:36:32,195 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-09-04 23:36:32,201 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-04 23:36:32,217 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-04 23:36:32,228 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-04 23:36:32,230 : INFO : EPOCH - 2 : training on 7020856 raw words (5727434 effective words) took 14.0s, 410102 effective words/s
# 2018-09-04 23:36:33,239 : INFO : EPOCH 3 - PROGRESS: at 7.37% examples, 435776 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:34,251 : INFO : EPOCH 3 - PROGRESS: at 15.36% examples, 436638 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:35,266 : INFO : EPOCH 3 - PROGRESS: at 22.86% examples, 433796 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:36,278 : INFO : EPOCH 3 - PROGRESS: at 30.62% examples, 438717 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:37,290 : INFO : EPOCH 3 - PROGRESS: at 38.82% examples, 437747 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:38,322 : INFO : EPOCH 3 - PROGRESS: at 45.11% examples, 423858 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:39,326 : INFO : EPOCH 3 - PROGRESS: at 53.55% examples, 430260 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:40,333 : INFO : EPOCH 3 - PROGRESS: at 61.53% examples, 430328 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:41,342 : INFO : EPOCH 3 - PROGRESS: at 68.95% examples, 432762 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:42,365 : INFO : EPOCH 3 - PROGRESS: at 76.60% examples, 433821 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:43,370 : INFO : EPOCH 3 - PROGRESS: at 84.79% examples, 436610 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:44,390 : INFO : EPOCH 3 - PROGRESS: at 92.36% examples, 435798 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:45,308 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-09-04 23:36:45,315 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-09-04 23:36:45,327 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-04 23:36:45,331 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-04 23:36:45,357 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-04 23:36:45,360 : INFO : EPOCH - 3 : training on 7020856 raw words (5727388 effective words) took 13.1s, 436456 effective words/s
# 2018-09-04 23:36:46,367 : INFO : EPOCH 4 - PROGRESS: at 7.36% examples, 425726 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:47,416 : INFO : EPOCH 4 - PROGRESS: at 14.92% examples, 418258 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:48,450 : INFO : EPOCH 4 - PROGRESS: at 23.04% examples, 428667 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:49,465 : INFO : EPOCH 4 - PROGRESS: at 30.28% examples, 427846 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:50,477 : INFO : EPOCH 4 - PROGRESS: at 37.96% examples, 424348 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:51,513 : INFO : EPOCH 4 - PROGRESS: at 46.02% examples, 427686 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:52,523 : INFO : EPOCH 4 - PROGRESS: at 53.79% examples, 427592 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:53,527 : INFO : EPOCH 4 - PROGRESS: at 61.58% examples, 427657 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:54,527 : INFO : EPOCH 4 - PROGRESS: at 68.76% examples, 428624 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:55,554 : INFO : EPOCH 4 - PROGRESS: at 76.14% examples, 428885 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:56,559 : INFO : EPOCH 4 - PROGRESS: at 84.30% examples, 431377 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:57,563 : INFO : EPOCH 4 - PROGRESS: at 91.59% examples, 429676 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:36:58,565 : INFO : EPOCH 4 - PROGRESS: at 99.35% examples, 430757 words/s, in_qsize 6, out_qsize 0
# 2018-09-04 23:36:58,610 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-09-04 23:36:58,614 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-09-04 23:36:58,628 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-04 23:36:58,646 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-04 23:36:58,672 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-04 23:36:58,673 : INFO : EPOCH - 4 : training on 7020856 raw words (5725903 effective words) took 13.3s, 430265 effective words/s
# 2018-09-04 23:36:59,702 : INFO : EPOCH 5 - PROGRESS: at 7.33% examples, 413587 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:00,710 : INFO : EPOCH 5 - PROGRESS: at 14.92% examples, 422609 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:01,728 : INFO : EPOCH 5 - PROGRESS: at 21.85% examples, 415995 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:02,747 : INFO : EPOCH 5 - PROGRESS: at 29.43% examples, 418958 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:03,772 : INFO : EPOCH 5 - PROGRESS: at 37.68% examples, 423067 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:04,779 : INFO : EPOCH 5 - PROGRESS: at 45.82% examples, 429072 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:05,792 : INFO : EPOCH 5 - PROGRESS: at 53.63% examples, 428850 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:06,797 : INFO : EPOCH 5 - PROGRESS: at 61.75% examples, 432074 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:07,823 : INFO : EPOCH 5 - PROGRESS: at 69.24% examples, 433225 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:08,825 : INFO : EPOCH 5 - PROGRESS: at 77.13% examples, 436095 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:09,845 : INFO : EPOCH 5 - PROGRESS: at 84.89% examples, 435936 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:10,859 : INFO : EPOCH 5 - PROGRESS: at 92.72% examples, 436106 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:11,707 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-09-04 23:37:11,718 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-09-04 23:37:11,734 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-04 23:37:11,737 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-04 23:37:11,752 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-04 23:37:11,754 : INFO : EPOCH - 5 : training on 7020856 raw words (5727041 effective words) took 13.1s, 438076 effective words/s
# 2018-09-04 23:37:11,755 : INFO : training on a 35104280 raw words (28635812 effective words) took 67.2s, 426198 effective words/s
# 2018-09-04 23:37:11,770 : INFO : Training iteration #2
# 2018-09-04 23:37:11,771 : INFO : training model with 5 workers on 215976 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 2018-09-04 23:37:12,789 : INFO : EPOCH 1 - PROGRESS: at 7.31% examples, 441330 words/s, in_qsize 8, out_qsize 1
# 2018-09-04 23:37:13,796 : INFO : EPOCH 1 - PROGRESS: at 15.23% examples, 447516 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:14,806 : INFO : EPOCH 1 - PROGRESS: at 23.47% examples, 440985 words/s, in_qsize 10, out_qsize 0
# 2018-09-04 23:37:15,825 : INFO : EPOCH 1 - PROGRESS: at 31.99% examples, 445321 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:16,846 : INFO : EPOCH 1 - PROGRESS: at 39.56% examples, 438762 words/s, in_qsize 10, out_qsize 0
# 2018-09-04 23:37:17,860 : INFO : EPOCH 1 - PROGRESS: at 46.14% examples, 429545 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:18,912 : INFO : EPOCH 1 - PROGRESS: at 53.46% examples, 424378 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:19,912 : INFO : EPOCH 1 - PROGRESS: at 60.87% examples, 425983 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:20,920 : INFO : EPOCH 1 - PROGRESS: at 68.90% examples, 428045 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:21,933 : INFO : EPOCH 1 - PROGRESS: at 76.62% examples, 431787 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:22,938 : INFO : EPOCH 1 - PROGRESS: at 84.36% examples, 432927 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:23,947 : INFO : EPOCH 1 - PROGRESS: at 92.71% examples, 434986 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:24,825 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-09-04 23:37:24,834 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-09-04 23:37:24,846 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-04 23:37:24,855 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-04 23:37:24,882 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-04 23:37:24,884 : INFO : EPOCH - 1 : training on 7020856 raw words (5726176 effective words) took 13.1s, 436890 effective words/s
# 2018-09-04 23:37:25,917 : INFO : EPOCH 2 - PROGRESS: at 7.29% examples, 428726 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:26,940 : INFO : EPOCH 2 - PROGRESS: at 15.23% examples, 441449 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:27,970 : INFO : EPOCH 2 - PROGRESS: at 24.11% examples, 447031 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:28,975 : INFO : EPOCH 2 - PROGRESS: at 32.65% examples, 449017 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:29,990 : INFO : EPOCH 2 - PROGRESS: at 40.50% examples, 447959 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:31,010 : INFO : EPOCH 2 - PROGRESS: at 48.58% examples, 450697 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:32,018 : INFO : EPOCH 2 - PROGRESS: at 56.98% examples, 452237 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:33,023 : INFO : EPOCH 2 - PROGRESS: at 65.00% examples, 453448 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:34,026 : INFO : EPOCH 2 - PROGRESS: at 72.89% examples, 454324 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:35,053 : INFO : EPOCH 2 - PROGRESS: at 80.85% examples, 454820 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:36,091 : INFO : EPOCH 2 - PROGRESS: at 88.91% examples, 454892 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:37,092 : INFO : EPOCH 2 - PROGRESS: at 96.98% examples, 455172 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:37,402 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-09-04 23:37:37,451 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-09-04 23:37:37,458 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-04 23:37:37,478 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-04 23:37:37,492 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-04 23:37:37,493 : INFO : EPOCH - 2 : training on 7020856 raw words (5727019 effective words) took 12.6s, 454534 effective words/s
# 2018-09-04 23:37:38,510 : INFO : EPOCH 3 - PROGRESS: at 7.51% examples, 450210 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:39,516 : INFO : EPOCH 3 - PROGRESS: at 15.61% examples, 457924 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:40,524 : INFO : EPOCH 3 - PROGRESS: at 24.49% examples, 460031 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:41,538 : INFO : EPOCH 3 - PROGRESS: at 33.09% examples, 460927 words/s, in_qsize 10, out_qsize 0
# 2018-09-04 23:37:42,573 : INFO : EPOCH 3 - PROGRESS: at 41.31% examples, 460351 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:43,593 : INFO : EPOCH 3 - PROGRESS: at 49.88% examples, 462281 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:44,596 : INFO : EPOCH 3 - PROGRESS: at 58.01% examples, 464497 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:45,616 : INFO : EPOCH 3 - PROGRESS: at 66.26% examples, 462688 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:46,637 : INFO : EPOCH 3 - PROGRESS: at 73.84% examples, 461380 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:47,656 : INFO : EPOCH 3 - PROGRESS: at 82.09% examples, 460931 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:48,659 : INFO : EPOCH 3 - PROGRESS: at 89.37% examples, 458411 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:49,668 : INFO : EPOCH 3 - PROGRESS: at 96.45% examples, 453954 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:50,079 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-09-04 23:37:50,123 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-09-04 23:37:50,140 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-04 23:37:50,141 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-04 23:37:50,142 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-04 23:37:50,144 : INFO : EPOCH - 3 : training on 7020856 raw words (5726665 effective words) took 12.6s, 452944 effective words/s
# 2018-09-04 23:37:51,155 : INFO : EPOCH 4 - PROGRESS: at 6.67% examples, 389446 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:52,160 : INFO : EPOCH 4 - PROGRESS: at 13.23% examples, 397599 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:53,203 : INFO : EPOCH 4 - PROGRESS: at 21.38% examples, 403065 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:54,221 : INFO : EPOCH 4 - PROGRESS: at 29.58% examples, 409352 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:55,238 : INFO : EPOCH 4 - PROGRESS: at 37.30% examples, 412567 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:56,239 : INFO : EPOCH 4 - PROGRESS: at 43.54% examples, 405437 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:57,276 : INFO : EPOCH 4 - PROGRESS: at 52.11% examples, 414575 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:58,285 : INFO : EPOCH 4 - PROGRESS: at 60.28% examples, 422644 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:37:59,292 : INFO : EPOCH 4 - PROGRESS: at 68.74% examples, 427734 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:00,319 : INFO : EPOCH 4 - PROGRESS: at 76.08% examples, 427823 words/s, in_qsize 10, out_qsize 0
# 2018-09-04 23:38:01,321 : INFO : EPOCH 4 - PROGRESS: at 83.10% examples, 424648 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:02,331 : INFO : EPOCH 4 - PROGRESS: at 90.19% examples, 424384 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:03,362 : INFO : EPOCH 4 - PROGRESS: at 98.60% examples, 427950 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:03,467 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-09-04 23:38:03,499 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-09-04 23:38:03,506 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-04 23:38:03,512 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-04 23:38:03,541 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-04 23:38:03,541 : INFO : EPOCH - 4 : training on 7020856 raw words (5727179 effective words) took 13.4s, 427830 effective words/s
# 2018-09-04 23:38:04,553 : INFO : EPOCH 5 - PROGRESS: at 6.92% examples, 412838 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:05,562 : INFO : EPOCH 5 - PROGRESS: at 14.23% examples, 419797 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:06,573 : INFO : EPOCH 5 - PROGRESS: at 22.96% examples, 431401 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:07,589 : INFO : EPOCH 5 - PROGRESS: at 30.61% examples, 425043 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:08,604 : INFO : EPOCH 5 - PROGRESS: at 38.85% examples, 432382 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:09,629 : INFO : EPOCH 5 - PROGRESS: at 46.49% examples, 432198 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:10,641 : INFO : EPOCH 5 - PROGRESS: at 54.87% examples, 438776 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:11,645 : INFO : EPOCH 5 - PROGRESS: at 63.29% examples, 443134 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:12,671 : INFO : EPOCH 5 - PROGRESS: at 71.20% examples, 444504 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:13,676 : INFO : EPOCH 5 - PROGRESS: at 79.16% examples, 446118 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:14,679 : INFO : EPOCH 5 - PROGRESS: at 87.24% examples, 448188 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:15,687 : INFO : EPOCH 5 - PROGRESS: at 95.32% examples, 449333 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:16,197 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-09-04 23:38:16,201 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-09-04 23:38:16,204 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-04 23:38:16,209 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-04 23:38:16,233 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-04 23:38:16,234 : INFO : EPOCH - 5 : training on 7020856 raw words (5726812 effective words) took 12.7s, 451403 effective words/s
# 2018-09-04 23:38:16,234 : INFO : training on a 35104280 raw words (28633851 effective words) took 64.5s, 444209 effective words/s
# 2018-09-04 23:38:16,247 : INFO : Training iteration #3
# 2018-09-04 23:38:16,248 : INFO : training model with 5 workers on 215976 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 2018-09-04 23:38:17,280 : INFO : EPOCH 1 - PROGRESS: at 8.08% examples, 458589 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:18,292 : INFO : EPOCH 1 - PROGRESS: at 16.21% examples, 460382 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:19,320 : INFO : EPOCH 1 - PROGRESS: at 24.67% examples, 462914 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:20,346 : INFO : EPOCH 1 - PROGRESS: at 32.68% examples, 465684 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:21,355 : INFO : EPOCH 1 - PROGRESS: at 41.26% examples, 468145 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:22,360 : INFO : EPOCH 1 - PROGRESS: at 49.35% examples, 465670 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:23,362 : INFO : EPOCH 1 - PROGRESS: at 57.86% examples, 464205 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:24,362 : INFO : EPOCH 1 - PROGRESS: at 65.56% examples, 463652 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:25,369 : INFO : EPOCH 1 - PROGRESS: at 73.84% examples, 464015 words/s, in_qsize 9, out_qsize 1
# 2018-09-04 23:38:26,384 : INFO : EPOCH 1 - PROGRESS: at 82.39% examples, 463575 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:27,386 : INFO : EPOCH 1 - PROGRESS: at 89.48% examples, 459596 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:28,402 : INFO : EPOCH 1 - PROGRESS: at 97.51% examples, 459701 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:28,650 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-09-04 23:38:28,662 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-09-04 23:38:28,676 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-04 23:38:28,700 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-04 23:38:28,704 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-04 23:38:28,705 : INFO : EPOCH - 1 : training on 7020856 raw words (5727725 effective words) took 12.5s, 460012 effective words/s
# 2018-09-04 23:38:29,722 : INFO : EPOCH 2 - PROGRESS: at 6.95% examples, 394835 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:30,747 : INFO : EPOCH 2 - PROGRESS: at 14.19% examples, 393947 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:31,756 : INFO : EPOCH 2 - PROGRESS: at 21.42% examples, 399983 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:32,768 : INFO : EPOCH 2 - PROGRESS: at 28.31% examples, 401705 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:33,770 : INFO : EPOCH 2 - PROGRESS: at 36.01% examples, 411744 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:34,771 : INFO : EPOCH 2 - PROGRESS: at 43.91% examples, 418518 words/s, in_qsize 8, out_qsize 1
# 2018-09-04 23:38:35,776 : INFO : EPOCH 2 - PROGRESS: at 52.28% examples, 424761 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:36,814 : INFO : EPOCH 2 - PROGRESS: at 60.95% examples, 429437 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:37,831 : INFO : EPOCH 2 - PROGRESS: at 68.24% examples, 429149 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:38,844 : INFO : EPOCH 2 - PROGRESS: at 75.98% examples, 428019 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:39,859 : INFO : EPOCH 2 - PROGRESS: at 84.23% examples, 430991 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:40,877 : INFO : EPOCH 2 - PROGRESS: at 92.34% examples, 434656 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:41,752 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-09-04 23:38:41,778 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-09-04 23:38:41,791 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-04 23:38:41,792 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-04 23:38:41,795 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-04 23:38:41,796 : INFO : EPOCH - 2 : training on 7020856 raw words (5727521 effective words) took 13.1s, 437684 effective words/s
# 2018-09-04 23:38:42,839 : INFO : EPOCH 3 - PROGRESS: at 7.83% examples, 438976 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:43,873 : INFO : EPOCH 3 - PROGRESS: at 16.25% examples, 453752 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:44,877 : INFO : EPOCH 3 - PROGRESS: at 24.64% examples, 461855 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:45,881 : INFO : EPOCH 3 - PROGRESS: at 32.34% examples, 463591 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:46,885 : INFO : EPOCH 3 - PROGRESS: at 40.34% examples, 459271 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:47,887 : INFO : EPOCH 3 - PROGRESS: at 48.73% examples, 461449 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:48,903 : INFO : EPOCH 3 - PROGRESS: at 57.21% examples, 459300 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:49,925 : INFO : EPOCH 3 - PROGRESS: at 65.12% examples, 459482 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:50,944 : INFO : EPOCH 3 - PROGRESS: at 73.31% examples, 459342 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:51,945 : INFO : EPOCH 3 - PROGRESS: at 81.45% examples, 458802 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:52,991 : INFO : EPOCH 3 - PROGRESS: at 89.53% examples, 457990 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:53,993 : INFO : EPOCH 3 - PROGRESS: at 97.78% examples, 459147 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:54,193 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-09-04 23:38:54,206 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-09-04 23:38:54,209 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-04 23:38:54,248 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-04 23:38:54,252 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-04 23:38:54,252 : INFO : EPOCH - 3 : training on 7020856 raw words (5727056 effective words) took 12.4s, 460063 effective words/s
# 2018-09-04 23:38:55,262 : INFO : EPOCH 4 - PROGRESS: at 7.99% examples, 460315 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:56,275 : INFO : EPOCH 4 - PROGRESS: at 16.08% examples, 461397 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:57,284 : INFO : EPOCH 4 - PROGRESS: at 24.27% examples, 461599 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:58,296 : INFO : EPOCH 4 - PROGRESS: at 32.22% examples, 466165 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:38:59,299 : INFO : EPOCH 4 - PROGRESS: at 40.75% examples, 469074 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:00,301 : INFO : EPOCH 4 - PROGRESS: at 48.45% examples, 462085 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:01,306 : INFO : EPOCH 4 - PROGRESS: at 57.22% examples, 462849 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:02,334 : INFO : EPOCH 4 - PROGRESS: at 65.46% examples, 463959 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:03,354 : INFO : EPOCH 4 - PROGRESS: at 74.23% examples, 466577 words/s, in_qsize 10, out_qsize 0
# 2018-09-04 23:39:04,356 : INFO : EPOCH 4 - PROGRESS: at 82.81% examples, 467406 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:05,357 : INFO : EPOCH 4 - PROGRESS: at 90.64% examples, 467738 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:06,364 : INFO : EPOCH 4 - PROGRESS: at 98.92% examples, 468180 words/s, in_qsize 8, out_qsize 0
# 2018-09-04 23:39:06,423 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-09-04 23:39:06,444 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-09-04 23:39:06,452 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-04 23:39:06,483 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-04 23:39:06,487 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-04 23:39:06,488 : INFO : EPOCH - 4 : training on 7020856 raw words (5727206 effective words) took 12.2s, 468252 effective words/s
# 2018-09-04 23:39:07,500 : INFO : EPOCH 5 - PROGRESS: at 7.59% examples, 436800 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:08,529 : INFO : EPOCH 5 - PROGRESS: at 15.63% examples, 447023 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:09,535 : INFO : EPOCH 5 - PROGRESS: at 24.05% examples, 452987 words/s, in_qsize 8, out_qsize 1
# 2018-09-04 23:39:10,535 : INFO : EPOCH 5 - PROGRESS: at 31.92% examples, 458273 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:11,546 : INFO : EPOCH 5 - PROGRESS: at 40.11% examples, 459007 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:12,548 : INFO : EPOCH 5 - PROGRESS: at 48.45% examples, 461191 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:13,556 : INFO : EPOCH 5 - PROGRESS: at 57.21% examples, 461678 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:14,559 : INFO : EPOCH 5 - PROGRESS: at 65.30% examples, 463551 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:15,566 : INFO : EPOCH 5 - PROGRESS: at 73.46% examples, 463596 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:16,566 : INFO : EPOCH 5 - PROGRESS: at 81.85% examples, 462703 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:17,586 : INFO : EPOCH 5 - PROGRESS: at 89.79% examples, 463216 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:18,591 : INFO : EPOCH 5 - PROGRESS: at 98.07% examples, 464477 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:18,770 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-09-04 23:39:18,822 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-09-04 23:39:18,824 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-04 23:39:18,825 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-04 23:39:18,825 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-04 23:39:18,826 : INFO : EPOCH - 5 : training on 7020856 raw words (5727509 effective words) took 12.3s, 464370 effective words/s
# 2018-09-04 23:39:18,827 : INFO : training on a 35104280 raw words (28637017 effective words) took 62.6s, 457636 effective words/s
# 2018-09-04 23:39:18,841 : INFO : Training iteration #4
# 2018-09-04 23:39:18,842 : INFO : training model with 5 workers on 215976 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 2018-09-04 23:39:19,867 : INFO : EPOCH 1 - PROGRESS: at 7.68% examples, 444262 words/s, in_qsize 8, out_qsize 1
# 2018-09-04 23:39:20,897 : INFO : EPOCH 1 - PROGRESS: at 16.25% examples, 457104 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:21,915 : INFO : EPOCH 1 - PROGRESS: at 24.42% examples, 466900 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:22,925 : INFO : EPOCH 1 - PROGRESS: at 33.26% examples, 465139 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:23,940 : INFO : EPOCH 1 - PROGRESS: at 41.99% examples, 466829 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:24,957 : INFO : EPOCH 1 - PROGRESS: at 50.00% examples, 467164 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:25,980 : INFO : EPOCH 1 - PROGRESS: at 58.42% examples, 464233 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:26,994 : INFO : EPOCH 1 - PROGRESS: at 66.63% examples, 465108 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:28,027 : INFO : EPOCH 1 - PROGRESS: at 74.97% examples, 465662 words/s, in_qsize 8, out_qsize 1
# 2018-09-04 23:39:29,033 : INFO : EPOCH 1 - PROGRESS: at 82.93% examples, 466865 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:30,042 : INFO : EPOCH 1 - PROGRESS: at 90.92% examples, 465960 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:31,049 : INFO : EPOCH 1 - PROGRESS: at 99.15% examples, 465928 words/s, in_qsize 6, out_qsize 0
# 2018-09-04 23:39:31,059 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-09-04 23:39:31,075 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-09-04 23:39:31,092 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-04 23:39:31,131 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-04 23:39:31,136 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-04 23:39:31,136 : INFO : EPOCH - 1 : training on 7020856 raw words (5726918 effective words) took 12.3s, 466337 effective words/s
# 2018-09-04 23:39:32,158 : INFO : EPOCH 2 - PROGRESS: at 7.99% examples, 450235 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:33,172 : INFO : EPOCH 2 - PROGRESS: at 16.38% examples, 463528 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:34,179 : INFO : EPOCH 2 - PROGRESS: at 24.27% examples, 468135 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:35,184 : INFO : EPOCH 2 - PROGRESS: at 32.49% examples, 457218 words/s, in_qsize 10, out_qsize 0
# 2018-09-04 23:39:36,204 : INFO : EPOCH 2 - PROGRESS: at 40.50% examples, 453338 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:37,213 : INFO : EPOCH 2 - PROGRESS: at 48.86% examples, 459010 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:38,239 : INFO : EPOCH 2 - PROGRESS: at 57.22% examples, 456070 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:39,254 : INFO : EPOCH 2 - PROGRESS: at 65.58% examples, 459868 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:40,271 : INFO : EPOCH 2 - PROGRESS: at 74.34% examples, 461975 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:41,295 : INFO : EPOCH 2 - PROGRESS: at 82.33% examples, 463024 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:42,322 : INFO : EPOCH 2 - PROGRESS: at 90.65% examples, 464161 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:43,323 : INFO : EPOCH 2 - PROGRESS: at 98.73% examples, 464987 words/s, in_qsize 8, out_qsize 0
# 2018-09-04 23:39:43,383 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-09-04 23:39:43,403 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-09-04 23:39:43,405 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-04 23:39:43,435 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-04 23:39:43,439 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-04 23:39:43,440 : INFO : EPOCH - 2 : training on 7020856 raw words (5726097 effective words) took 12.3s, 465531 effective words/s
# 2018-09-04 23:39:44,444 : INFO : EPOCH 3 - PROGRESS: at 7.84% examples, 451268 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:45,460 : INFO : EPOCH 3 - PROGRESS: at 15.94% examples, 456239 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:46,464 : INFO : EPOCH 3 - PROGRESS: at 23.77% examples, 460781 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:47,495 : INFO : EPOCH 3 - PROGRESS: at 32.73% examples, 460180 words/s, in_qsize 10, out_qsize 0
# 2018-09-04 23:39:48,523 : INFO : EPOCH 3 - PROGRESS: at 38.85% examples, 435571 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:49,556 : INFO : EPOCH 3 - PROGRESS: at 48.33% examples, 450251 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:50,581 : INFO : EPOCH 3 - PROGRESS: at 57.65% examples, 457116 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:39:51,596 : INFO : EPOCH 3 - PROGRESS: at 66.98% examples, 466573 words/s, in_qsize 9, out_qsize 0
# ...
# 2018-09-04 23:44:12,601 : INFO : EPOCH 3 - PROGRESS: at 22.27% examples, 427858 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:13,607 : INFO : EPOCH 3 - PROGRESS: at 30.57% examples, 436417 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:14,631 : INFO : EPOCH 3 - PROGRESS: at 39.70% examples, 446870 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:15,645 : INFO : EPOCH 3 - PROGRESS: at 48.35% examples, 452571 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:16,655 : INFO : EPOCH 3 - PROGRESS: at 56.14% examples, 454197 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:17,660 : INFO : EPOCH 3 - PROGRESS: at 64.69% examples, 458387 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:18,663 : INFO : EPOCH 3 - PROGRESS: at 72.61% examples, 462083 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:19,680 : INFO : EPOCH 3 - PROGRESS: at 81.35% examples, 465153 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:20,681 : INFO : EPOCH 3 - PROGRESS: at 90.25% examples, 466094 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:21,683 : INFO : EPOCH 3 - PROGRESS: at 99.03% examples, 466880 words/s, in_qsize 8, out_qsize 0
# 2018-09-04 23:44:21,737 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-09-04 23:44:21,745 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-09-04 23:44:21,756 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-04 23:44:21,778 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-04 23:44:21,784 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-04 23:44:21,785 : INFO : EPOCH - 3 : training on 7020856 raw words (5726687 effective words) took 12.3s, 467263 effective words/s
# 2018-09-04 23:44:22,797 : INFO : EPOCH 4 - PROGRESS: at 7.79% examples, 449335 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:23,816 : INFO : EPOCH 4 - PROGRESS: at 15.87% examples, 466652 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:24,822 : INFO : EPOCH 4 - PROGRESS: at 24.59% examples, 474084 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:25,851 : INFO : EPOCH 4 - PROGRESS: at 33.17% examples, 475452 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:26,859 : INFO : EPOCH 4 - PROGRESS: at 42.02% examples, 474072 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:27,869 : INFO : EPOCH 4 - PROGRESS: at 50.50% examples, 475748 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:28,870 : INFO : EPOCH 4 - PROGRESS: at 58.47% examples, 476286 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:29,885 : INFO : EPOCH 4 - PROGRESS: at 66.92% examples, 477715 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:30,886 : INFO : EPOCH 4 - PROGRESS: at 74.94% examples, 480111 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:31,894 : INFO : EPOCH 4 - PROGRESS: at 83.62% examples, 479533 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:32,923 : INFO : EPOCH 4 - PROGRESS: at 92.42% examples, 479117 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:33,690 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-09-04 23:44:33,697 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-09-04 23:44:33,720 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-04 23:44:33,725 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-04 23:44:33,756 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-04 23:44:33,757 : INFO : EPOCH - 4 : training on 7020856 raw words (5726605 effective words) took 12.0s, 478765 effective words/s
# 2018-09-04 23:44:34,779 : INFO : EPOCH 5 - PROGRESS: at 7.97% examples, 458396 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:35,812 : INFO : EPOCH 5 - PROGRESS: at 16.18% examples, 468612 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:36,818 : INFO : EPOCH 5 - PROGRESS: at 24.87% examples, 477755 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:37,822 : INFO : EPOCH 5 - PROGRESS: at 33.46% examples, 478974 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:38,835 : INFO : EPOCH 5 - PROGRESS: at 42.16% examples, 475337 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:39,838 : INFO : EPOCH 5 - PROGRESS: at 50.05% examples, 470900 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:40,848 : INFO : EPOCH 5 - PROGRESS: at 57.62% examples, 469406 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:41,865 : INFO : EPOCH 5 - PROGRESS: at 66.24% examples, 471896 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:42,870 : INFO : EPOCH 5 - PROGRESS: at 74.17% examples, 474159 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:43,889 : INFO : EPOCH 5 - PROGRESS: at 82.15% examples, 470765 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:44,910 : INFO : EPOCH 5 - PROGRESS: at 91.04% examples, 470069 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:45,841 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-09-04 23:44:45,871 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-09-04 23:44:45,872 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-04 23:44:45,901 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-04 23:44:45,910 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-04 23:44:45,912 : INFO : EPOCH - 5 : training on 7020856 raw words (5727706 effective words) took 12.1s, 471622 effective words/s
# 2018-09-04 23:44:45,914 : INFO : training on a 35104280 raw words (28634015 effective words) took 60.9s, 470389 effective words/s
# 2018-09-04 23:44:45,931 : INFO : Training iteration #9
# 2018-09-04 23:44:45,935 : INFO : training model with 5 workers on 215976 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 2018-09-04 23:44:46,946 : INFO : EPOCH 1 - PROGRESS: at 8.34% examples, 459183 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:47,951 : INFO : EPOCH 1 - PROGRESS: at 16.41% examples, 477975 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:48,957 : INFO : EPOCH 1 - PROGRESS: at 24.96% examples, 472456 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:49,963 : INFO : EPOCH 1 - PROGRESS: at 33.59% examples, 477618 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:50,991 : INFO : EPOCH 1 - PROGRESS: at 42.48% examples, 481257 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:51,998 : INFO : EPOCH 1 - PROGRESS: at 50.71% examples, 480587 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:53,006 : INFO : EPOCH 1 - PROGRESS: at 59.60% examples, 481176 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:54,009 : INFO : EPOCH 1 - PROGRESS: at 67.63% examples, 479381 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:55,010 : INFO : EPOCH 1 - PROGRESS: at 75.01% examples, 473187 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:56,032 : INFO : EPOCH 1 - PROGRESS: at 82.09% examples, 465038 words/s, in_qsize 10, out_qsize 0
# 2018-09-04 23:44:57,063 : INFO : EPOCH 1 - PROGRESS: at 90.53% examples, 464516 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:58,065 : INFO : EPOCH 1 - PROGRESS: at 98.50% examples, 465586 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:44:58,201 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-09-04 23:44:58,212 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-09-04 23:44:58,236 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-04 23:44:58,265 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-04 23:44:58,271 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-04 23:44:58,273 : INFO : EPOCH - 1 : training on 7020856 raw words (5726416 effective words) took 12.3s, 464477 effective words/s
# 2018-09-04 23:44:59,286 : INFO : EPOCH 2 - PROGRESS: at 8.11% examples, 456671 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:00,311 : INFO : EPOCH 2 - PROGRESS: at 14.76% examples, 425220 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:01,313 : INFO : EPOCH 2 - PROGRESS: at 21.08% examples, 396983 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:02,317 : INFO : EPOCH 2 - PROGRESS: at 25.81% examples, 363024 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:03,330 : INFO : EPOCH 2 - PROGRESS: at 31.47% examples, 355715 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:04,358 : INFO : EPOCH 2 - PROGRESS: at 36.57% examples, 344850 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:05,389 : INFO : EPOCH 2 - PROGRESS: at 44.12% examples, 355258 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:06,390 : INFO : EPOCH 2 - PROGRESS: at 48.60% examples, 344169 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:07,393 : INFO : EPOCH 2 - PROGRESS: at 54.04% examples, 338650 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:08,400 : INFO : EPOCH 2 - PROGRESS: at 60.65% examples, 342089 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:09,412 : INFO : EPOCH 2 - PROGRESS: at 66.67% examples, 341548 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:10,435 : INFO : EPOCH 2 - PROGRESS: at 74.10% examples, 348198 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:11,440 : INFO : EPOCH 2 - PROGRESS: at 82.56% examples, 358205 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:12,442 : INFO : EPOCH 2 - PROGRESS: at 91.44% examples, 367819 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:13,431 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-09-04 23:45:13,439 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-09-04 23:45:13,493 : INFO : EPOCH 2 - PROGRESS: at 99.69% examples, 375460 words/s, in_qsize 2, out_qsize 1
# 2018-09-04 23:45:13,494 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-04 23:45:13,501 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-04 23:45:13,502 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-04 23:45:13,503 : INFO : EPOCH - 2 : training on 7020856 raw words (5726824 effective words) took 15.2s, 376168 effective words/s
# 2018-09-04 23:45:14,516 : INFO : EPOCH 3 - PROGRESS: at 8.29% examples, 459213 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:15,553 : INFO : EPOCH 3 - PROGRESS: at 16.41% examples, 469917 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:16,576 : INFO : EPOCH 3 - PROGRESS: at 25.56% examples, 474821 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:17,593 : INFO : EPOCH 3 - PROGRESS: at 34.00% examples, 477689 words/s, in_qsize 10, out_qsize 0
# 2018-09-04 23:45:18,595 : INFO : EPOCH 3 - PROGRESS: at 42.58% examples, 478892 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:19,618 : INFO : EPOCH 3 - PROGRESS: at 50.29% examples, 472731 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:20,623 : INFO : EPOCH 3 - PROGRESS: at 58.16% examples, 466949 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:21,644 : INFO : EPOCH 3 - PROGRESS: at 66.46% examples, 466986 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:22,660 : INFO : EPOCH 3 - PROGRESS: at 75.17% examples, 470751 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:23,677 : INFO : EPOCH 3 - PROGRESS: at 84.07% examples, 472639 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:24,688 : INFO : EPOCH 3 - PROGRESS: at 92.77% examples, 473279 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:25,524 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-09-04 23:45:25,529 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-09-04 23:45:25,557 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-04 23:45:25,559 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-04 23:45:25,580 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-04 23:45:25,581 : INFO : EPOCH - 3 : training on 7020856 raw words (5726959 effective words) took 12.1s, 474555 effective words/s
# 2018-09-04 23:45:26,598 : INFO : EPOCH 4 - PROGRESS: at 8.15% examples, 455255 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:27,626 : INFO : EPOCH 4 - PROGRESS: at 16.54% examples, 474695 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:28,629 : INFO : EPOCH 4 - PROGRESS: at 25.72% examples, 482331 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:29,645 : INFO : EPOCH 4 - PROGRESS: at 33.88% examples, 478491 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:30,654 : INFO : EPOCH 4 - PROGRESS: at 42.48% examples, 479369 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:31,659 : INFO : EPOCH 4 - PROGRESS: at 50.71% examples, 479180 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:32,689 : INFO : EPOCH 4 - PROGRESS: at 59.57% examples, 478525 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:33,718 : INFO : EPOCH 4 - PROGRESS: at 68.26% examples, 479338 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:34,742 : INFO : EPOCH 4 - PROGRESS: at 77.04% examples, 480064 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:35,746 : INFO : EPOCH 4 - PROGRESS: at 85.60% examples, 481406 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:36,748 : INFO : EPOCH 4 - PROGRESS: at 94.11% examples, 481404 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:37,491 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-09-04 23:45:37,501 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-09-04 23:45:37,548 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-04 23:45:37,551 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-04 23:45:37,567 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-04 23:45:37,568 : INFO : EPOCH - 4 : training on 7020856 raw words (5726049 effective words) took 12.0s, 478013 effective words/s
# 2018-09-04 23:45:38,578 : INFO : EPOCH 5 - PROGRESS: at 8.50% examples, 474449 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:39,595 : INFO : EPOCH 5 - PROGRESS: at 16.39% examples, 475613 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:40,597 : INFO : EPOCH 5 - PROGRESS: at 24.98% examples, 471257 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:41,601 : INFO : EPOCH 5 - PROGRESS: at 32.98% examples, 470626 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:42,607 : INFO : EPOCH 5 - PROGRESS: at 41.82% examples, 473289 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:43,607 : INFO : EPOCH 5 - PROGRESS: at 49.74% examples, 473946 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:44,619 : INFO : EPOCH 5 - PROGRESS: at 58.82% examples, 476293 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:45,657 : INFO : EPOCH 5 - PROGRESS: at 67.30% examples, 476114 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:46,680 : INFO : EPOCH 5 - PROGRESS: at 76.22% examples, 478687 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:47,681 : INFO : EPOCH 5 - PROGRESS: at 84.57% examples, 478480 words/s, in_qsize 10, out_qsize 0
# 2018-09-04 23:45:48,684 : INFO : EPOCH 5 - PROGRESS: at 93.08% examples, 477726 words/s, in_qsize 9, out_qsize 0
# 2018-09-04 23:45:49,447 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-09-04 23:45:49,454 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-09-04 23:45:49,489 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-04 23:45:49,504 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-04 23:45:49,509 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-04 23:45:49,510 : INFO : EPOCH - 5 : training on 7020856 raw words (5728065 effective words) took 11.9s, 480023 effective words/s
# 2018-09-04 23:45:49,511 : INFO : training on a 35104280 raw words (28634313 effective words) took 63.6s, 450429 effective words/s
# 2018-09-04 23:45:49,532 : INFO : Saving trained Doc2Vec model
# 2018-09-04 23:45:49,537 : INFO : saving Doc2Vec object under d2v.model, separately None
# 2018-09-04 23:45:49,538 : INFO : storing np array 'syn1neg' to d2v.model.trainables.syn1neg.npy
# 2018-09-04 23:45:49,822 : INFO : storing np array 'vectors' to d2v.model.wv.vectors.npy
# 2018-09-04 23:45:50,701 : INFO : saved d2v.model

# %%
# from above:
#2018-09-04 22:27:22,334 : INFO : Saving trained Doc2Vec model
#2018-09-04 22:27:22,336 : INFO : saving Doc2Vec object under d2v.model, separately None
#2018-09-04 22:27:22,337 : INFO : storing np array 'syn1neg' to d2v.model.trainables.syn1neg.npy
#2018-09-04 22:27:22,642 : INFO : storing np array 'vectors' to d2v.model.wv.vectors.npy
#2018-09-04 22:27:23,597 : INFO : saved d2v.model
# TODO figure out how to juad load d2v.model in future versions

classifier = train_classifier(d2v_model, x_train, y_train)
# Out:
# 2018-09-04 23:47:35,563 : INFO : Classifier training
# 2018-09-04 23:47:40,393 : INFO : Training predicted classes: ['No' 'Yes']
# 2018-09-04 23:47:40,397 : INFO : Training accuracy: 0.9915062287655719
# 2018-09-04 23:47:40,437 : INFO : Training F1 score: 0.9915163728060931
#              precision    recall  f1-score   support
#
#          No       0.98      1.00      0.99       714
#         Yes       1.00      0.99      0.99      1052
#
# avg / total       0.99      0.99      0.99      1766

# %%
# TODO figure out how to optimize recall of certain label
test_classifier(d2v_model, classifier, x_test, y_test)
# Out:
# 2018-09-04 23:47:40,448 : INFO : Classifier testing
# 2018-09-04 23:47:40,463 : INFO : Testing predicted classes: ['No' 'Yes']
# 2018-09-04 23:47:40,491 : INFO : Testing accuracy: 0.9027149321266968
# 2018-09-04 23:47:40,499 : INFO : Testing F1 score: 0.9021579851139084
#              precision    recall  f1-score   support
#
#          No       0.91      0.85      0.88       186
#         Yes       0.90      0.94      0.92       256
#
# avg / total       0.90      0.90      0.90       442

# %%
#output = classifier.predict('This movies really boring. I did not like that the acting was so dry.'.split())

#output

vector1 = d2v_model.infer_vector('We launched last week. We are proud to invest in this company. We are announcing are investment in this company. You can listen in the podcast.'.split())
vector2 = d2v_model.infer_vector("For early stage companies hiring is difficult. To raise a Series A, you need to talk to the right investors. Founders should have this.".split())

output = classifier.predict_proba([vector1, vector2])
#output = classifier.predict([vector1, vector2])
output

# no is higher in first vector, so we want Yes from second element as final score
# Out:
# array([[0.68576883, 0.31423117],
#        [0.68649043, 0.31350957]])

# %%
formula = urllib.parse.urlencode({'filterByFormula': 'AND({On Topic}="",{Topic Score}="",{Text}!="")'})
airtable_list_url = 'https://api.airtable.com/v0/appasJt3vfOA4OjKU/Posts?' + formula

response = requests.get(airtable_list_url, headers = {'Authorization': 'Bearer ' + airtable_api_key})
payload = json.loads(response.content)

for post in payload['records']:
    proba_output = classifier.predict_proba([d2v_model.infer_vector(post['fields']['Text'])])
    predicted_label = classifier.predict([d2v_model.infer_vector(post['fields']['Text'])])
    
    data = {'fields': {
        'Topic Score': proba_output[0][1],
        'On Topic Prediction': predicted_label[0]
    }}
    
    if True or predicted_label[0] == 'No':
    
        response = requests.patch('https://api.airtable.com/v0/appasJt3vfOA4OjKU/Posts' + '/' + post['id'], headers = airtable_headers, data = json.dumps(data))
    
        if response.status_code != 200:
            print('hit error saving data')
            print(response.content)
            print(data)
            raise RuntimeError(response.content)
